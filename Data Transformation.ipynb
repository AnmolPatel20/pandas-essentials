# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor              Film  Year            Genre  \
# 0       Shah Rukh Khan           Pathaan  2023           Action
# 1          Salman Khan   Tiger Zinda Hai  2017           Action
# 2           Aamir Khan            Dangal  2016        Biography
# 3        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 4        Ranveer Singh         Padmaavat  2018       Historical
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6        Rajkummar Rao             Stree  2018    Horror Comedy
# 7       Hrithik Roshan               War  2019           Action
# 8         Akshay Kumar        Good Newwz  2019           Comedy
# 9        Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 10        Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgica  2019           Action
#
#     BoxOffice(INR Cror)  IMDb
# 0                  1050   7.2
# 1                   565   6.5
# 2                  2024   8.4
# ...

# %%
df.sort_values("Year")
# Out:
#                  Actor              Film  Year            Genre  \
# 2           Aamir Khan            Dangal  2016        Biography
# 1          Salman Khan   Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 4        Ranveer Singh         Padmaavat  2018       Historical
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6        Rajkummar Rao             Stree  2018    Horror Comedy
# 7       Hrithik Roshan               War  2019           Action
# 8         Akshay Kumar        Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgica  2019           Action
# 3        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 9        Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 0       Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb
# 2                  2024   8.4
# 1                   565   6.5
# 10                  201   6.1
# ...

# %%
df.sort_values("Year",ascending=False)
# Out:
#                  Actor              Film  Year            Genre  \
# 0       Shah Rukh Khan           Pathaan  2023           Action
# 3        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 9        Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 7       Hrithik Roshan               War  2019           Action
# 8         Akshay Kumar        Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgica  2019           Action
# 4        Ranveer Singh         Padmaavat  2018       Historical
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6        Rajkummar Rao             Stree  2018    Horror Comedy
# 1          Salman Khan   Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 2           Aamir Khan            Dangal  2016        Biography
#
#     BoxOffice(INR Cror)  IMDb
# 0                  1050   7.2
# 3                   431   5.6
# 9                   266   5.9
# ...

# %%
df.sort_values(["Year","IMDb"]) #Firstly sort according Year if it is tie then it will rang according to imdb
# Out:
#                  Actor              Film  Year            Genre  \
# 2           Aamir Khan            Dangal  2016        Biography
# 10        Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 1          Salman Khan   Tiger Zinda Hai  2017           Action
# 4        Ranveer Singh         Padmaavat  2018       Historical
# 6        Rajkummar Rao             Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 7       Hrithik Roshan               War  2019           Action
# 8         Akshay Kumar        Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgica  2019           Action
# 3        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 9        Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 0       Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb
# 2                  2024   8.4
# 10                  201   6.1
# 1                   565   6.5
# ...

# %%
df2=df.sort_values(["Year","IMDb"]).copy()

# %%
df2
# Out:
#                  Actor              Film  Year            Genre  \
# 2           Aamir Khan            Dangal  2016        Biography
# 10        Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 1          Salman Khan   Tiger Zinda Hai  2017           Action
# 4        Ranveer Singh         Padmaavat  2018       Historical
# 6        Rajkummar Rao             Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 7       Hrithik Roshan               War  2019           Action
# 8         Akshay Kumar        Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgica  2019           Action
# 3        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 9        Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 0       Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb
# 2                  2024   8.4
# 10                  201   6.1
# 1                   565   6.5
# ...

# %%
df2.reset_index()   # reset indexes without value change
# Out:
#     index               Actor              Film  Year            Genre  \
# 0       2          Aamir Khan            Dangal  2016        Biography
# 1      10        Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 2       1         Salman Khan   Tiger Zinda Hai  2017           Action
# 3       4       Ranveer Singh         Padmaavat  2018       Historical
# 4       6       Rajkummar Rao             Stree  2018    Horror Comedy
# 5       5  Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6       7      Hrithik Roshan               War  2019           Action
# 7       8        Akshay Kumar        Good Newwz  2019           Comedy
# 8      11       Vicky Kaushal  Uri: The Surgica  2019           Action
# 9       3       Ranbir Kapoor        Brahmastra  2022          Fantasy
# 10      9       Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 11      0      Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb
# ...

# %%
df2.reset_index(drop=True , inplace =True )   #removes previous index that become column in data and inplace helps to replace all the data of index in orignal df2 file

# %%
df2
# Out:
#                  Actor              Film  Year            Genre  \
# 0           Aamir Khan            Dangal  2016        Biography
# 1         Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 2          Salman Khan   Tiger Zinda Hai  2017           Action
# 3        Ranveer Singh         Padmaavat  2018       Historical
# 4        Rajkummar Rao             Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6       Hrithik Roshan               War  2019           Action
# 7         Akshay Kumar        Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgica  2019           Action
# 9        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 10       Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 11      Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb
# 0                  2024   8.4
# 1                   201   6.1
# 2                   565   6.5
# ...

# %%
 df2["Rank"] = df2["IMDb"].rank()  #create a new column according to rank of a given column

# %%
df2
# Out:
#                  Actor              Film  Year            Genre  \
# 0           Aamir Khan            Dangal  2016        Biography
# 1         Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 2          Salman Khan   Tiger Zinda Hai  2017           Action
# 3        Ranveer Singh         Padmaavat  2018       Historical
# 4        Rajkummar Rao             Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6       Hrithik Roshan               War  2019           Action
# 7         Akshay Kumar        Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgica  2019           Action
# 9        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 10       Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 11      Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb  Rank
# 0                  2024   8.4  12.0
# 1                   201   6.1   3.0
# ...

# %%
df2["Rank"] = df2["IMDb"].rank(ascending=False , method="dense")  #dense helps to give values not in decimal or float value but gives you in integer form

# %%
df2
# Out:
#                  Actor              Film  Year            Genre  \
# 0           Aamir Khan            Dangal  2016        Biography
# 1         Varun Dhawan  Badrinath Ki Dul  2017  Romantic Comedy
# 2          Salman Khan   Tiger Zinda Hai  2017           Action
# 3        Ranveer Singh         Padmaavat  2018       Historical
# 4        Rajkummar Rao             Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana         Andhadhun  2018         Thriller
# 6       Hrithik Roshan               War  2019           Action
# 7         Akshay Kumar        Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgica  2019           Action
# 9        Ranbir Kapoor        Brahmastra  2022          Fantasy
# 10       Kartik Aaryan   Bhool Bhulaiyaa  2022    Horror Comedy
# 11      Shah Rukh Khan           Pathaan  2023           Action
#
#     BoxOffice(INR Cror)  IMDb  Rank
# 0                  2024   8.4   1.0
# 1                   201   6.1   8.0
# ...
